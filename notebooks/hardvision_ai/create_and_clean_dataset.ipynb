# %% [markdown]
# # 🖥️ Cuaderno para la creación del dataset del modelo
#
# El objetivo principal de este cuaderno es crear el dataset que utilizará nuestro modelo, de forma que, al recibir la imagen de un componente, pueda identificar correctamente qué tipo de componente es.
#
# **Primera parte: crear dataset con las URLs**
#
# ### 👨‍💻 Autores del proyecto
#
# * [Alejandro Barrionuevo Rosado](https://github.com/Alejandro-BR)
# * [Alvaro López Guerrero](https://github.com/Alvalogue72)
# * [Andrei Munteanu Popa](https://github.com/andu8705)
#
# Máster de FP en Inteligencia Artifical y Big Data - CPIFP Alan Turing - `Curso 2025/2026`

# %% [markdown]
# ## Importaciones

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Obtención de datos
#
# Estos datos fueron obtenidos mediante técnicas de web scraping en otros cuadernos Jupyter, y posteriormente recopilados para su análisis en este proyecto.
#
# ### Fuentes:
#
# * [pc componentes](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pccomponentes/productos_pccomponentes.csv)
#
# * [techpowerup](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/techpowerup/productos_cpu.csv)
#
# * [cases pcpartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cases_pspartpicker.csv)
#
# * [cpu cooler pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cpu_cooler_pspartpicker.csv)
#
# * [cpu pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cpu_pspartpicker.csv)
#
# * [gpu pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/gpu_pspartpicker.csv)
#
# <!-- [monitor pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/monitor_pspartpicker.csv) -->
#
# * [motherboard pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/motherboard_pspartpicker.csv)
#
# <!-- [os pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/os_pspartpicker.csv) -->
#
# * [psu pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/psu_pspartpicker.csv)
#
# * [ram pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/ram_pspartpicker.csv)
#
# * [storage pspartpicker](https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/storage_pspartpicker.csv)

# %%
df_pccomponentes = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pccomponentes/productos_pccomponentes.csv")

# %%
df_techpowerup = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/techpowerup/productos_cpu.csv")

# %%
# Cases
df_cases_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cases_pspartpicker.csv")

# CPU Coolers
df_cpu_cooler_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cpu_cooler_pspartpicker.csv")

# CPUs
df_cpu_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/cpu_pspartpicker.csv")

# GPUs
df_gpu_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/gpu_pspartpicker.csv")

# Motherboards
df_motherboard_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/motherboard_pspartpicker.csv")

# PSUs
df_psu_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/psu_pspartpicker.csv")

# RAM
df_ram_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/ram_pspartpicker.csv")

# Storage
df_storage_pcpartpicker = pd.read_csv("https://raw.githubusercontent.com/Latency-Zero-tfm/HardVisionAI/refs/heads/main/data/raw/pcpartpicker/csv/storage_pspartpicker.csv")

# %% [markdown]
# ## Descripción de los datos

# %% [markdown]
# ![pc componentes](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSl83mVntFb7c9i0-UaL-ndNZDZDevPJMraIg&s)
#
# ### PC Componentes
#
# Este dataset contiene **9.055 registros**. Disponemos del **tipo de componente**, que será el *target* de nuestro modelo inicial, así como del **nombre** y el **precio**, que no utilizaremos en esta fase pero resultarán útiles en etapas posteriores del proyecto.
#
# Por último, contamos con la **URL de la imagen**, que será la principal fuente de datos para entrenar el modelo.

# %%
df_pccomponentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9055 entries, 0 to 9054
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   component_type  9055 non-null   object
#  1   name            9055 non-null   object
#  2   price           8648 non-null   float64
#  3   image_url       9055 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 283.1+ KB

# %%
df_pccomponentes
# Out:
#               component_type  \
# 0                placas-base
# 1                placas-base
# 2                placas-base
# 3                placas-base
# 4                placas-base
# ...                      ...
# 9050  tarjetas-sonido?page=2
# 9051  tarjetas-sonido?page=2
# 9052  tarjetas-sonido?page=2
# 9053  tarjetas-sonido?page=2
# 9054  tarjetas-sonido?page=2
#
#                                                    name   price  \
# 0                                     MSI B550M PRO-VDH   87.99
# 1                             MSI B850 GAMING PLUS WIFI  209.26
# 2                              Gigabyte B760M DS3H DDR4   92.99
# 3     Placa Base MSI MAG B850 Tomahawk Wifi AM5 DDR5...  234.99
# 4                                ASUS PRIME B550M-A/CSM   87.99
# ...                                                 ...     ...
# 9050  Tarjeta de sonido DeLock 67071 USB-C aluminio ...   40.99
# 9051  Tarjeta de sonido KeepOut HXADAP 7.1 USB con e...   18.90
# 9052  Tarjeta de sonido Nedis USCR10051BU 5.1 canale...   14.99
# 9053  Tarjeta de sonido Speed Link SL-8850-BK-01 USB...   11.32
# 9054        Vention Tarjeta de Sonido Externa USB Plata    3.48
#
#                                               image_url
# 0     https://thumb.pccomponentes.com/w-530-530/arti...
# 1     https://thumb.pccomponentes.com/w-530-530/arti...
# 2     https://thumb.pccomponentes.com/w-530-530/arti...
# 3     https://thumb.pccomponentes.com/w-530-530/arti...
# 4     https://thumb.pccomponentes.com/w-530-530/arti...
# ...                                                 ...
# 9050  https://thumb.pccomponentes.com/w-530-530/arti...
# 9051  https://thumb.pccomponentes.com/w-530-530/arti...
# 9052  https://thumb.pccomponentes.com/w-530-530/arti...
# 9053  https://thumb.pccomponentes.com/w-530-530/arti...
# 9054  https://thumb.pccomponentes.com/w-530-530/arti...
#
# [9055 rows x 4 columns]

# %% [markdown]
# #### Valores nulos
# En este subapartado vamos a analizar cuántos valores nulos existen y en qué variables se encuentran, para poder realizar una limpieza de datos más efectiva.

# %%
print("-" * 50)
df_pccomponentes.info()
print("-" * 50)
print(df_pccomponentes.isnull().sum())
print("-" * 50)
# Out:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9055 entries, 0 to 9054
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   component_type  9055 non-null   object
#  1   name            9055 non-null   object
#  2   price           8648 non-null   float64
#  3   image_url       9055 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 283.1+ KB
# --------------------------------------------------
# component_type      0
# name                0
# price             407
# image_url           0
# dtype: int64
# --------------------------------------------------

# %% [markdown]
# Podemos observar que los únicos valores nulos se encuentran en la columna `price`, y dado que esta columna no es relevante para el dataset que vamos a construir, su presencia no afecta al proceso.

# %% [markdown]
# #### Verificación del tipo de datos de `component_type`
#
# Aquí revisaremos el **tipo de datos** de la columna `component_type` para asegurarnos de que esté en el formato adecuado para el entrenamiento del modelo.

# %%
df_pccomponentes["component_type"].unique()
# Out:
# array(['placas-base', 'placas-base?page=2', 'placas-base?page=3',
#        'placas-base?page=4', 'placas-base?page=5', 'placas-base?page=6',
#        'placas-base?page=7', 'placas-base?page=8', 'placas-base?page=9',
#        'placas-base?page=10', 'placas-base?page=11',
#        'placas-base?page=12', 'placas-base?page=13',
#        'placas-base?page=14', 'placas-base?page=15',
#        'placas-base?page=16', 'placas-base?page=17',
#        'placas-base?page=18', 'placas-base?page=19', 'tarjetas-graficas',
#        'tarjetas-graficas?page=2', 'tarjetas-graficas?page=3',
#        'tarjetas-graficas?page=4', 'tarjetas-graficas?page=5',
#        'tarjetas-graficas?page=6', 'tarjetas-graficas?page=7',
#        'tarjetas-graficas?page=8', 'tarjetas-graficas?page=9',
#        'tarjetas-graficas?page=10', 'tarjetas-graficas?page=11',
#        'tarjetas-graficas?page=12', 'tarjetas-graficas?page=13',
#        'tarjetas-graficas?page=14', 'procesadores', 'procesadores?page=2',
#        'procesadores?page=3', 'procesadores?page=4',
#        'procesadores?page=5', 'procesadores?page=6',
#        'procesadores?page=7', 'discos-duros', 'discos-duros?page=2',
#        'discos-duros?page=3', 'discos-duros?page=4',
#        'discos-duros?page=5', 'discos-duros?page=6',
#        'discos-duros?page=7', 'discos-duros?page=8',
#        'discos-duros?page=9', 'discos-duros?page=10',
#        'discos-duros?page=11', 'discos-duros?page=12',
#        'discos-duros?page=13', 'discos-duros?page=14',
#        'discos-duros?page=15', 'discos-duros?page=16',
#        'discos-duros?page=17', 'discos-duros?page=18',
#        'discos-duros?page=19', 'discos-duros?page=20',
#        'discos-duros?page=21', 'discos-duros?page=22',
#        'discos-duros?page=23', 'discos-duros?page=24',
#        'discos-duros?page=25', 'discos-duros?page=26',
#        'discos-duros?page=27', 'discos-duros?page=28',
#        'discos-duros?page=29', 'discos-duros?page=30',
#        'discos-duros?page=31', 'discos-duros?page=32',
#        'discos-duros?page=33', 'discos-duros?page=34',
#        'discos-duros?page=35', 'discos-duros?page=36',
#        'discos-duros?page=37', 'discos-duros?page=38',
#        'discos-duros?page=39', 'discos-duros?page=40',
#        'discos-duros?page=41', 'discos-duros?page=42',
#        'discos-duros?page=43', 'discos-duros?page=44',
#        'discos-duros?page=45', 'memorias-ram', 'memorias-ram?page=2',
#        'memorias-ram?page=3', 'memorias-ram?page=4',
#        'memorias-ram?page=5', 'memorias-ram?page=6',
#        'memorias-ram?page=7', 'memorias-ram?page=8',
#        'memorias-ram?page=9', 'memorias-ram?page=10',
#        'memorias-ram?page=11', 'memorias-ram?page=12',
#        'memorias-ram?page=13', 'memorias-ram?page=14',
#        'memorias-ram?page=15', 'memorias-ram?page=16',
#        'memorias-ram?page=17', 'memorias-ram?page=18',
#        'memorias-ram?page=19', 'memorias-ram?page=20',
#        'memorias-ram?page=21', 'memorias-ram?page=22',
#        'memorias-ram?page=23', 'memorias-ram?page=24',
#        'memorias-ram?page=25', 'memorias-ram?page=26',
#        'memorias-ram?page=27', 'memorias-ram?page=28',
#        'memorias-ram?page=29', 'memorias-ram?page=30',
#        'memorias-ram?page=31', 'cajas-pc', 'cajas-pc?page=2',
#        'cajas-pc?page=3', 'cajas-pc?page=4', 'cajas-pc?page=5',
#        'cajas-pc?page=6', 'cajas-pc?page=7', 'cajas-pc?page=8',
#        'cajas-pc?page=9', 'cajas-pc?page=10', 'cajas-pc?page=11',
#        'cajas-pc?page=12', 'cajas-pc?page=13', 'cajas-pc?page=14',
#        'cajas-pc?page=15', 'cajas-pc?page=16', 'cajas-pc?page=17',
#        'cajas-pc?page=18', 'cajas-pc?page=19', 'cajas-pc?page=20',
#        'cajas-pc?page=21', 'cajas-pc?page=22', 'cajas-pc?page=23',
#        'cajas-pc?page=24', 'cajas-pc?page=25', 'cajas-pc?page=26',
#        'cajas-pc?page=27', 'cajas-pc?page=28', 'cajas-pc?page=29',
#        'cajas-pc?page=30', 'cajas-pc?page=31', 'cajas-pc?page=32',
#        'cajas-pc?page=33', 'cajas-pc?page=34', 'cajas-pc?page=35',
#        'cajas-pc?page=36', 'cajas-pc?page=37', 'cajas-pc?page=38',
#        'cajas-pc?page=39', 'cajas-pc?page=40', 'cajas-pc?page=41',
#        'cajas-pc?page=42', 'cajas-pc?page=43', 'cajas-pc?page=44',
#        'fuentes-alimentacion', 'fuentes-alimentacion?page=2',
#        'fuentes-alimentacion?page=3', 'fuentes-alimentacion?page=4',
#        'fuentes-alimentacion?page=5', 'fuentes-alimentacion?page=6',
#        'fuentes-alimentacion?page=7', 'fuentes-alimentacion?page=8',
#        'fuentes-alimentacion?page=9', 'fuentes-alimentacion?page=10',
#        'fuentes-alimentacion?page=11', 'fuentes-alimentacion?page=12',
#        'fuentes-alimentacion?page=13', 'fuentes-alimentacion?page=14',
#        'fuentes-alimentacion?page=15', 'fuentes-alimentacion?page=16',
#        'fuentes-alimentacion?page=17', 'fuentes-alimentacion?page=18',
#        'fuentes-alimentacion?page=19', 'fuentes-alimentacion?page=20',
#        'fuentes-alimentacion?page=21', 'fuentes-alimentacion?page=22',
#        'fuentes-alimentacion?page=23', 'refrigeracion-liquida',
#        'refrigeracion-liquida?page=2', 'refrigeracion-liquida?page=3',
#        'refrigeracion-liquida?page=4', 'refrigeracion-liquida?page=5',
#        'refrigeracion-liquida?page=6', 'refrigeracion-liquida?page=7',
#        'refrigeracion-liquida?page=8', 'refrigeracion-liquida?page=9',
#        'refrigeracion-liquida?page=10', 'refrigeracion-liquida?page=11',
#        'refrigeracion-liquida?page=12', 'refrigeracion-liquida?page=13',
#        'refrigeracion-liquida?page=14', 'refrigeracion-liquida?page=15',
#        'refrigeracion-liquida?page=16', 'refrigeracion-liquida?page=17',
#        'refrigeracion-liquida?page=18', 'refrigeracion-liquida?page=19',
#        'refrigeracion-liquida?page=20', 'ventiladores-suplementarios',
#        'ventiladores-suplementarios?page=2',
#        'ventiladores-suplementarios?page=3',
#        'ventiladores-suplementarios?page=4',
#        'ventiladores-suplementarios?page=5',
#        'ventiladores-suplementarios?page=6',
#        'ventiladores-suplementarios?page=7',
#        'ventiladores-suplementarios?page=8',
#        'ventiladores-suplementarios?page=9',
#        'ventiladores-suplementarios?page=10',
#        'ventiladores-suplementarios?page=11',
#        'ventiladores-suplementarios?page=12',
#        'ventiladores-suplementarios?page=13',
#        'ventiladores-suplementarios?page=14',
#        'ventiladores-suplementarios?page=15',
#        'ventiladores-suplementarios?page=16', 'ventiladores-cpu',
#        'ventiladores-cpu?page=2', 'ventiladores-cpu?page=3',
#        'ventiladores-cpu?page=4', 'ventiladores-cpu?page=5',
#        'ventiladores-cpu?page=6', 'ventiladores-cpu?page=7',
#        'ventiladores-cpu?page=8', 'ventiladores-cpu?page=9',
#        'ventiladores-cpu?page=10', 'tarjetas-sonido',
#        'tarjetas-sonido?page=2'], dtype=object)

# %% [markdown]
# Podemos observar que será necesario normalizar los nombres de los componentes para mantener un estándar consistente en el dataset.

# %% [markdown]
# ![Techpowerup](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGil8G9FDmK_uxP_S7LgnB7b-KeXQFnNYwWw&s)
#
# ### Techpowerup
#
# Este dataset contiene **127 registros**. Incluye la URL del producto, el nombre y la URL de la imagen. Para este modelo únicamente utilizaremos la **imagen del producto**.

# %%
df_techpowerup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   URL         127 non-null    object
#  1   Name        127 non-null    object
#  2   Chip Image  127 non-null    object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %%
df_techpowerup
# Out:
#                                                    URL  \
# 0    https://www.techpowerup.com/cpu-specs/core-ult...
# 1    https://www.techpowerup.com/cpu-specs/core-ult...
# 2    https://www.techpowerup.com/cpu-specs/core-ult...
# 3    https://www.techpowerup.com/cpu-specs/core-ult...
# 4    https://www.techpowerup.com/cpu-specs/ryzen-ai...
# ..                                                 ...
# 122  https://www.techpowerup.com/cpu-specs/core-i9-...
# 123  https://www.techpowerup.com/cpu-specs/ryzen-5-...
# 124  https://www.techpowerup.com/cpu-specs/ryzen-5-...
# 125  https://www.techpowerup.com/cpu-specs/ryzen-3-...
# 126  https://www.techpowerup.com/cpu-specs/athlon-3...
#
#                         Name  \
# 0    Intel Core Ultra 9 386H
# 1    Intel Core Ultra 7 366H
# 2    Intel Core Ultra 7 356H
# 3    Intel Core Ultra 5 336H
# 4      AMD Ryzen AI Max+ 388
# ..                       ...
# 122      Intel Core i9-9900K
# 123        AMD Ryzen 5 3550H
# 124      AMD Ryzen 5 5500X3D
# 125        AMD Ryzen 3 4300U
# 126    AMD Athlon 3000G (FH)
#
#                                             Chip Image
# 0    https://tpucdn.com/cpu-specs/images/chips/4305...
# 1    https://tpucdn.com/cpu-specs/images/chips/4306...
# 2    https://tpucdn.com/cpu-specs/images/chips/4307...
# 3    https://tpucdn.com/cpu-specs/images/chips/4309...
# 4    https://tpucdn.com/cpu-specs/images/chips/4312...
# ..                                                 ...
# 122  https://tpucdn.com/cpu-specs/images/chips/2098...
# 123  https://tpucdn.com/cpu-specs/images/connectivi...
# 124  https://tpucdn.com/cpu-specs/images/connectivi...
# 125  https://tpucdn.com/cpu-specs/images/chips/2286...
# 126  https://tpucdn.com/cpu-specs/images/chips/2243...
#
# [127 rows x 3 columns]

# %% [markdown]
# #### Valores nulos
# En este subapartado vamos a analizar cuántos valores nulos existen y en qué variables se encuentran, para poder realizar una limpieza de datos más efectiva.

# %%
print("-" * 50)
df_techpowerup.info()
print("-" * 50)
print(df_techpowerup.isnull().sum())
print("-" * 50)
# Out:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   URL         127 non-null    object
#  1   Name        127 non-null    object
#  2   Chip Image  127 non-null    object
# dtypes: object(3)
# memory usage: 3.1+ KB
# --------------------------------------------------
# URL           0
# Name          0
# Chip Image    0
# dtype: int64
# --------------------------------------------------

# %% [markdown]
# Podemos observar que no existen valores nulos en este dataset.

# %% [markdown]
# ![Techpowerup](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRfH5WMITGcIa8-71mKahtQ2J7JhCk3d-z-A&s)
#
# ### PCPartPicker
#
# Estos datasets contienen información de distintos componentes de PC, pero para nuestro proyecto solo utilizaremos la imagen de cada producto:
#
# * **df_cases_pcpartpicker**: Contiene información sobre cajas de PC, incluyendo tipo, color, compatibilidad con fuentes de poder, panel lateral, capacidad de almacenamiento interno, rating, precio e imagen.
# * **df_cpu_cooler_pcpartpicker**: Incluye características de refrigeración de CPU, como velocidad de ventilador, nivel de ruido, color, tamaño de radiador, rating, precio e imagen.
# * **df_cpu_pcpartpicker**: Contiene datos de procesadores, incluyendo cantidad de núcleos, frecuencia base y boost, arquitectura, TDP, gráficos integrados, rating, precio e imagen.
# * **df_gpu_pcpartpicker**: Incluye información de tarjetas gráficas, como chipset, memoria, velocidad de reloj, color, longitud, rating, precio e imagen.
# * **df_motherboard_pcpartpicker**: Incluye información sobre placas base, como socket, factor de forma, memoria máxima, ranuras de memoria, color, rating, precio e imagen.
# * **df_psu_pcpartpicker**: Incluye información de fuentes de poder, como tipo, eficiencia, potencia, modularidad, color, rating, precio e imagen.
# * **df_ram_pcpartpicker**: Contiene datos de memoria RAM, incluyendo velocidad, módulos, latencias, color, rating, precio y imagen.
# * **df_storage_pcpartpicker**: Incluye información de dispositivos de almacenamiento, como capacidad, precio por GB, tipo, caché, factor de forma, interfaz, rating, precio e imagen.

# %%
# Cases
print("df_cases_pcpartpicker info:")
print(df_cases_pcpartpicker.info())
print('---')

# CPU Coolers
print("df_cpu_cooler_pcpartpicker info:")
print(df_cpu_cooler_pcpartpicker.info())
print('---')

# CPUs
print("df_cpu_pcpartpicker info:")
print(df_cpu_pcpartpicker.info())
print('---')

# GPUs
print("df_gpu_pcpartpicker info:")
print(df_gpu_pcpartpicker.info())
print('---')

# Motherboards
print("df_motherboard_pcpartpicker info:")
print(df_motherboard_pcpartpicker.info())
print('---')

# PSUs
print("df_psu_pcpartpicker info:")
print(df_psu_pcpartpicker.info())
print('---')

# RAM
print("df_ram_pcpartpicker info:")
print(df_ram_pcpartpicker.info())
print('---')

# Storage
print("df_storage_pcpartpicker info:")
print(df_storage_pcpartpicker.info())
print('---')
# Out:
# df_cases_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                100 non-null    object
#  1   Type                100 non-null    object
#  2   Color               100 non-null    object
#  3   Power Supply        100 non-null    object
#  4   Side Panel          100 non-null    object
#  5   External Volume     100 non-null    object
#  6   Internal 3.5" Bays  100 non-null    object
#  7   Rating              100 non-null    object
#  8   Price               100 non-null    object
#  9   image_url           100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_cpu_cooler_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           100 non-null    object
#  1   Fan RPM        100 non-null    object
#  2   Noise Level    100 non-null    object
#  3   Color          100 non-null    object
#  4   Radiator Size  100 non-null    object
#  5   Rating         100 non-null    object
#  6   Price          100 non-null    object
#  7   image_url      100 non-null    object
# dtypes: object(8)
# memory usage: 6.4+ KB
# None
# ---
# df_cpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          100 non-null    object
#  1   Core Count                    100 non-null    object
#  2   Performance Core Clock        100 non-null    object
#  3   Performance Core Boost Clock  100 non-null    object
#  4   Microarchitecture             100 non-null    object
#  5   TDP                           100 non-null    object
#  6   Integrated Graphics           100 non-null    object
#  7   Rating                        100 non-null    object
#  8   Price                         100 non-null    object
#  9   image_url                     100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_gpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         100 non-null    object
#  1   Chipset      100 non-null    object
#  2   Memory       100 non-null    object
#  3   Core Clock   100 non-null    object
#  4   Boost Clock  100 non-null    object
#  5   Color        100 non-null    object
#  6   Length       100 non-null    object
#  7   Rating       100 non-null    object
#  8   Price        100 non-null    object
#  9   image_url    100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_motherboard_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          100 non-null    object
#  1   Socket / CPU  100 non-null    object
#  2   Form Factor   100 non-null    object
#  3   Memory Max    100 non-null    object
#  4   Memory Slots  100 non-null    object
#  5   Color         100 non-null    object
#  6   Rating        100 non-null    object
#  7   Price         100 non-null    object
#  8   image_url     100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB
# None
# ---
# df_psu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Type               100 non-null    object
#  2   Efficiency Rating  100 non-null    object
#  3   Wattage            100 non-null    object
#  4   Modular            100 non-null    object
#  5   Color              100 non-null    object
#  6   Rating             100 non-null    object
#  7   Price              100 non-null    object
#  8   image_url          100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB
# None
# ---
# df_ram_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                100 non-null    object
#  1   Speed               100 non-null    object
#  2   Modules             100 non-null    object
#  3   Price / GB          100 non-null    object
#  4   Color               100 non-null    object
#  5   First Word Latency  100 non-null    object
#  6   CAS Latency         100 non-null    object
#  7   Rating              100 non-null    object
#  8   Price               100 non-null    object
#  9   image_url           100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_storage_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         100 non-null    object
#  1   Capacity     100 non-null    object
#  2   Price / GB   100 non-null    object
#  3   Type         100 non-null    object
#  4   Cache        100 non-null    object
#  5   Form Factor  100 non-null    object
#  6   Interface    100 non-null    object
#  7   Rating       100 non-null    object
#  8   Price        100 non-null    object
#  9   image_url    100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---

# %%
df_gpu_pcpartpicker
# Out:
#                                        Name                       Chipset  \
# 0                   Gigabyte GAMING OC (13)      ChipsetRadeon RX 9060 XT
# 1            Gigabyte WINDFORCE OC SFF (10)       ChipsetGeForce RTX 5070
# 2                    Asus ROG Astral OC (8)       ChipsetGeForce RTX 5090
# 3   MSI GeForce RTX 3060 Ventus 2X 12G (35)  ChipsetGeForce RTX 3060 12GB
# 4                   Gigabyte GAMING OC (29)      ChipsetRadeon RX 9070 XT
# ..                                      ...                           ...
# 95             Asus ROG STRIX GAMING OC (1)    ChipsetGeForce RTX 5070 Ti
# 96                 ASRock Challenger D (36)         ChipsetRadeon RX 6600
# 97                MSI SUPRIM LIQUID SOC (5)       ChipsetGeForce RTX 5090
# 98                            XFX Swift (5)      ChipsetRadeon RX 9070 XT
# 99                     Asus DUAL EVO OC (0)    ChipsetGeForce RTX 4060 Ti
#
#          Memory          Core Clock          Boost Clock                Color  \
# 0   Memory16 GB  Core Clock2220 MHz  Boost Clock3320 MHz           ColorBlack
# 1   Memory12 GB  Core Clock2160 MHz  Boost Clock2542 MHz           ColorBlack
# 2   Memory32 GB  Core Clock2010 MHz  Boost Clock2610 MHz  ColorBlack / Silver
# 3   Memory12 GB  Core Clock1320 MHz  Boost Clock1777 MHz           ColorBlack
# 4   Memory16 GB  Core Clock2520 MHz  Boost Clock3060 MHz           ColorBlack
# ..          ...                 ...                  ...                  ...
# 95  Memory16 GB  Core Clock2300 MHz  Boost Clock2625 MHz  ColorBlack / Silver
# 96   Memory8 GB  Core Clock1626 MHz          Boost Clock           ColorBlack
# 97  Memory32 GB  Core Clock2010 MHz          Boost Clock  ColorBlack / Silver
# 98  Memory16 GB  Core Clock1660 MHz  Boost Clock2970 MHz           ColorWhite
# 99   Memory8 GB  Core Clock2310 MHz  Boost Clock2595 MHz           ColorBlack
#
#           Length Rating                    Price  \
# 0   Length281 mm   (13)               €460.49Add
# 1   Length282 mm   (10)               €698.81Add
# 2   Length358 mm    (8)              €4449.99Add
# 3   Length235 mm   (35)               €565.50Add
# 4   Length288 mm   (29)               €749.95Add
# ..           ...    ...                      ...
# 95  Length332 mm    (1)              €1326.90Add
# 96  Length269 mm   (36)                      Add
# 97  Length280 mm    (5)  Out of stock€2899.68Add
# 98  Length325 mm    (5)               €736.00Add
# 99  Length227 mm    (0)                      Add
#
#                                             image_url
# 0   https://cdna.pcpartpicker.com/static/forever/i...
# 1   https://cdna.pcpartpicker.com/static/forever/i...
# 2   https://cdna.pcpartpicker.com/static/forever/i...
# 3   https://cdna.pcpartpicker.com/static/forever/i...
# 4   https://cdna.pcpartpicker.com/static/forever/i...
# ..                                                ...
# 95  https://cdna.pcpartpicker.com/static/forever/i...
# 96  https://cdna.pcpartpicker.com/static/forever/i...
# 97  https://cdna.pcpartpicker.com/static/forever/i...
# 98  https://cdna.pcpartpicker.com/static/forever/i...
# 99  https://cdna.pcpartpicker.com/static/forever/i...
#
# [100 rows x 10 columns]

# %% [markdown]
# #### Valores nulos
# En este subapartado vamos a analizar cuántos valores nulos existen y en qué variables se encuentran, para poder realizar una limpieza de datos más efectiva.

# %%
# Cases
print("df_cases_pcpartpicker null values:")
print(df_cases_pcpartpicker.isnull().sum())
print('---')

# CPU Coolers
print("df_cpu_cooler_pcpartpicker null values:")
print(df_cpu_cooler_pcpartpicker.isnull().sum())
print('---')

# CPUs
print("df_cpu_pcpartpicker null values:")
print(df_cpu_pcpartpicker.isnull().sum())
print('---')

# GPUs
print("df_gpu_pcpartpicker null values:")
print(df_gpu_pcpartpicker.isnull().sum())
print('---')

# Motherboards
print("df_motherboard_pcpartpicker null values:")
print(df_motherboard_pcpartpicker.isnull().sum())
print('---')

# PSUs
print("df_psu_pcpartpicker null values:")
print(df_psu_pcpartpicker.isnull().sum())
print('---')

# RAM
print("df_ram_pcpartpicker null values:")
print(df_ram_pcpartpicker.isnull().sum())
print('---')

# Storage
print("df_storage_pcpartpicker null values:")
print(df_storage_pcpartpicker.isnull().sum())
print('---')
# Out:
# df_cases_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_cpu_cooler_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_cpu_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_gpu_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_motherboard_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_psu_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_ram_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---
# df_storage_pcpartpicker null values:
# image_url    0
# label        0
# dtype: int64
# ---

# %% [markdown]
# Podemos observar que no existen valores nulos en estos datasets.

# %% [markdown]
# ## Preparación de los datos
#
# En este apartado vamos a limpiar el dataset para dejarlo listo para el modelo.

# %% [markdown]
# ### `component_type`
#
# Vamos a **unificar y estandarizar los nombres** de los componentes en la columna `component_type` para mantener consistencia y facilitar el entrenamiento del modelo.
#
# Posteriormente, **renombraremos esta columna a `label`**, que será nuestro *target* final.

# %%
df_pccomponentes['component_type'] = df_pccomponentes['component_type'].str.replace(r'\?page=\d+', '', regex=True)
df_pccomponentes['component_type'].unique()
# Out:
# array(['placas-base', 'tarjetas-graficas', 'procesadores', 'discos-duros',
#        'memorias-ram', 'cajas-pc', 'fuentes-alimentacion',
#        'refrigeracion-liquida', 'ventiladores-suplementarios',
#        'ventiladores-cpu', 'tarjetas-sonido'], dtype=object)

# %% [markdown]
# ### Mapeo de etiquetas a inglés
#
# Para estandarizar y facilitar el uso del dataset, **mapearemos los nombres de los componentes del español al inglés** de la siguiente manera:
#
# | Español                     | Inglés         |
# | --------------------------- | -------------- |
# | placas-base                 | motherboard    |
# | tarjetas-graficas           | gpu            |
# | procesadores                | cpu            |
# | discos-duros                | hard_drive     |
# | memorias-ram                | ram            |
# | cajas-pc                    | pc_case        |
# | fuentes-alimentacion        | power_supply   |
# | refrigeracion-liquida       | liquid_cooling |
# | ventiladores-suplementarios | case_fan       |
# | ventiladores-cpu            | cpu_fan        |
# | tarjetas-sonido             | sound_card     |

# %%
mapping = {
    'placas-base': 'motherboard',
    'tarjetas-graficas': 'gpu',
    'procesadores': 'cpu',
    'discos-duros': 'hard_drive',
    'memorias-ram': 'ram',
    'cajas-pc': 'pc_case',
    'fuentes-alimentacion': 'power_supply',
    'refrigeracion-liquida': 'liquid_cooling',
    'ventiladores-suplementarios': 'case_fan',
    'ventiladores-cpu': 'cpu_fan',
    'tarjetas-sonido': 'sound_card'
}

df_pccomponentes['component_type'] = df_pccomponentes['component_type'].str.replace(r'\?page=\d+', '', regex=True)
df_pccomponentes['component_type'] = df_pccomponentes['component_type'].map(mapping)

# %% [markdown]
# ### Renombrar la columna a `label`

# %%
df_pccomponentes = df_pccomponentes.rename(columns={'component_type': 'label'})
print(df_pccomponentes['label'].unique())
# Out:
# ['motherboard' 'gpu' 'cpu' 'hard_drive' 'ram' 'pc_case' 'power_supply'
#  'liquid_cooling' 'case_fan' 'cpu_fan' 'sound_card']

# %% [markdown]
# ### Creación de la columna `label` en el resto de datasets
#
# Vamos a crear una columna **`label`** que servirá como *target* para el modelo.
#
# Además, se incorporará un nuevo tipo de componente: `liquid_cooling`

# %%
df_techpowerup['label'] = 'cpu'
df_techpowerup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   URL         127 non-null    object
#  1   Name        127 non-null    object
#  2   Chip Image  127 non-null    object
#  3   label       127 non-null    object
# dtypes: object(4)
# memory usage: 4.1+ KB

# %% [markdown]
# liquid_cooling

# %%
df_cases_pcpartpicker['label'] = 'pc_case'
df_cpu_cooler_pcpartpicker['label'] = 'liquid_cooling'
df_cpu_pcpartpicker['label'] = 'cpu'
df_gpu_pcpartpicker['label'] = 'gpu'
df_motherboard_pcpartpicker['label'] = 'motherboard'
df_psu_pcpartpicker['label'] = 'power_supply'
df_ram_pcpartpicker['label'] = 'ram'
df_storage_pcpartpicker['label'] = 'hard_drive'

print("df_cases_pcpartpicker info:")
print(df_cases_pcpartpicker.info())
print('---')

print("df_cpu_cooler_pcpartpicker info:")
print(df_cpu_cooler_pcpartpicker.info())
print('---')

print("df_cpu_pcpartpicker info:")
print(df_cpu_pcpartpicker.info())
print('---')

print("df_gpu_pcpartpicker info:")
print(df_gpu_pcpartpicker.info())
print('---')

print("df_motherboard_pcpartpicker info:")
print(df_motherboard_pcpartpicker.info())
print('---')

print("df_psu_pcpartpicker info:")
print(df_psu_pcpartpicker.info())
print('---')

print("df_ram_pcpartpicker info:")
print(df_ram_pcpartpicker.info())
print('---')

print("df_storage_pcpartpicker info:")
print(df_storage_pcpartpicker.info())
print('---')
# Out:
# df_cases_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                100 non-null    object
#  1   Type                100 non-null    object
#  2   Color               100 non-null    object
#  3   Power Supply        100 non-null    object
#  4   Side Panel          100 non-null    object
#  5   External Volume     100 non-null    object
#  6   Internal 3.5" Bays  100 non-null    object
#  7   Rating              100 non-null    object
#  8   Price               100 non-null    object
#  9   image_url           100 non-null    object
#  10  label               100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB
# None
# ---
# df_cpu_cooler_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           100 non-null    object
#  1   Fan RPM        100 non-null    object
#  2   Noise Level    100 non-null    object
#  3   Color          100 non-null    object
#  4   Radiator Size  100 non-null    object
#  5   Rating         100 non-null    object
#  6   Price          100 non-null    object
#  7   image_url      100 non-null    object
#  8   label          100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB
# None
# ---
# df_cpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          100 non-null    object
#  1   Core Count                    100 non-null    object
#  2   Performance Core Clock        100 non-null    object
#  3   Performance Core Boost Clock  100 non-null    object
#  4   Microarchitecture             100 non-null    object
#  5   TDP                           100 non-null    object
#  6   Integrated Graphics           100 non-null    object
#  7   Rating                        100 non-null    object
#  8   Price                         100 non-null    object
#  9   image_url                     100 non-null    object
#  10  label                         100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB
# None
# ---
# df_gpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         100 non-null    object
#  1   Chipset      100 non-null    object
#  2   Memory       100 non-null    object
#  3   Core Clock   100 non-null    object
#  4   Boost Clock  100 non-null    object
#  5   Color        100 non-null    object
#  6   Length       100 non-null    object
#  7   Rating       100 non-null    object
#  8   Price        100 non-null    object
#  9   image_url    100 non-null    object
#  10  label        100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB
# None
# ---
# df_motherboard_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          100 non-null    object
#  1   Socket / CPU  100 non-null    object
#  2   Form Factor   100 non-null    object
#  3   Memory Max    100 non-null    object
#  4   Memory Slots  100 non-null    object
#  5   Color         100 non-null    object
#  6   Rating        100 non-null    object
#  7   Price         100 non-null    object
#  8   image_url     100 non-null    object
#  9   label         100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_psu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Type               100 non-null    object
#  2   Efficiency Rating  100 non-null    object
#  3   Wattage            100 non-null    object
#  4   Modular            100 non-null    object
#  5   Color              100 non-null    object
#  6   Rating             100 non-null    object
#  7   Price              100 non-null    object
#  8   image_url          100 non-null    object
#  9   label              100 non-null    object
# dtypes: object(10)
# memory usage: 7.9+ KB
# None
# ---
# df_ram_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                100 non-null    object
#  1   Speed               100 non-null    object
#  2   Modules             100 non-null    object
#  3   Price / GB          100 non-null    object
#  4   Color               100 non-null    object
#  5   First Word Latency  100 non-null    object
#  6   CAS Latency         100 non-null    object
#  7   Rating              100 non-null    object
#  8   Price               100 non-null    object
#  9   image_url           100 non-null    object
#  10  label               100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB
# None
# ---
# df_storage_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         100 non-null    object
#  1   Capacity     100 non-null    object
#  2   Price / GB   100 non-null    object
#  3   Type         100 non-null    object
#  4   Cache        100 non-null    object
#  5   Form Factor  100 non-null    object
#  6   Interface    100 non-null    object
#  7   Rating       100 non-null    object
#  8   Price        100 non-null    object
#  9   image_url    100 non-null    object
#  10  label        100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB
# None
# ---

# %% [markdown]
# ### Renombrar la columna de imagen
#
# Para mantener consistencia en todos los datasets, vamos a cambiar el nombre de la columna que contiene la URL de la imagen a `image_url`.

# %%
df_techpowerup = df_techpowerup.rename(columns={'Chip Image': 'image_url'})

# %% [markdown]
# ### Filtrado de columnas relevantes
#
# En este paso vamos a **conservar únicamente las columnas necesarias** para nuestro modelo, descartando el resto de información que no utilizaremos por ahora.

# %%
df_pccomponentes = df_pccomponentes[["image_url", "label"]]
df_pccomponentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9055 entries, 0 to 9054
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  9055 non-null   object
#  1   label      9055 non-null   object
# dtypes: object(2)
# memory usage: 141.6+ KB

# %%
df_techpowerup = df_techpowerup[["image_url", "label"]]
df_techpowerup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  127 non-null    object
#  1   label      127 non-null    object
# dtypes: object(2)
# memory usage: 2.1+ KB

# %%
df_cases_pcpartpicker = df_cases_pcpartpicker[["image_url", "label"]]
df_cpu_cooler_pcpartpicker = df_cpu_cooler_pcpartpicker[["image_url", "label"]]
df_cpu_pcpartpicker = df_cpu_pcpartpicker[["image_url", "label"]]
df_gpu_pcpartpicker = df_gpu_pcpartpicker[["image_url", "label"]]
df_motherboard_pcpartpicker = df_motherboard_pcpartpicker[["image_url", "label"]]
df_psu_pcpartpicker = df_psu_pcpartpicker[["image_url", "label"]]
df_ram_pcpartpicker = df_ram_pcpartpicker[["image_url", "label"]]
df_storage_pcpartpicker = df_storage_pcpartpicker[["image_url", "label"]]

print("df_cases_pcpartpicker info:")
print(df_cases_pcpartpicker.info())
print('---')

print("df_cpu_cooler_pcpartpicker info:")
print(df_cpu_cooler_pcpartpicker.info())
print('---')

print("df_cpu_pcpartpicker info:")
print(df_cpu_pcpartpicker.info())
print('---')

print("df_gpu_pcpartpicker info:")
print(df_gpu_pcpartpicker.info())
print('---')

print("df_motherboard_pcpartpicker info:")
print(df_motherboard_pcpartpicker.info())
print('---')

print("df_psu_pcpartpicker info:")
print(df_psu_pcpartpicker.info())
print('---')

print("df_ram_pcpartpicker info:")
print(df_ram_pcpartpicker.info())
print('---')

print("df_storage_pcpartpicker info:")
print(df_storage_pcpartpicker.info())
print('---')
# Out:
# df_cases_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_cpu_cooler_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_cpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_gpu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_motherboard_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_psu_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_ram_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---
# df_storage_pcpartpicker info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  100 non-null    object
#  1   label      100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None
# ---

# %% [markdown]
# ### Creación del DataFrame
#
# En este primer paso vamos a construir el **DataFrame** que contendrá toda la información necesaria para nuestro dataset.

# %%
df = pd.concat([
    df_pccomponentes,
    df_techpowerup,
    df_cases_pcpartpicker,
    df_cpu_cooler_pcpartpicker,
    df_cpu_pcpartpicker,
    df_gpu_pcpartpicker,
    df_motherboard_pcpartpicker,
    df_psu_pcpartpicker,
    df_ram_pcpartpicker,
    df_storage_pcpartpicker
], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9982 entries, 0 to 9981
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  9982 non-null   object
#  1   label      9982 non-null   object
# dtypes: object(2)
# memory usage: 156.1+ KB

# %%
df
# Out:
#                                               image_url        label
# 0     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 1     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 2     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 3     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 4     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# ...                                                 ...          ...
# 9977  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9978  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9979  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9980  https://m.media-amazon.com/images/I/31s-wKnYDv...   hard_drive
# 9981  https://m.media-amazon.com/images/I/51jzvyPoV6...   hard_drive
#
# [9982 rows x 2 columns]

# %% [markdown]
# El dataset final contiene `9982` registros, cada uno con la URL de la imagen de un componente de PC y su correspondiente etiqueta (label) que indica el tipo de componente.

# %% [markdown]
# ## Guardamos el dataset
#
# A continuación guardamos el dataset final en un archivo CSV para poder usarlo en otros cuadernos o descargarlo a nuestra máquina:

# %%
# df.to_csv('components_01.csv', index=False)
# df.to_json('components_01.json', orient='records')

# %%
# from google.colab import files

# Descargar a tu máquina local
# files.download('components_01.csv')
# files.download('components_01.json')

# %% [markdown]
# ## Visualización de los datos
#
# Las siguientes gráficas muestran la cantidad y proporción de imágenes por tipo de componente, ofreciendo una visión clara de la distribución del dataset.

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9982 entries, 0 to 9981
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image_url  9982 non-null   object
#  1   label      9982 non-null   object
# dtypes: object(2)
# memory usage: 156.1+ KB
#                                               image_url        label
# 0     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 1     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 2     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 3     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# 4     https://thumb.pccomponentes.com/w-530-530/arti...  motherboard
# ...                                                 ...          ...
# 9977  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9978  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9979  https://cdna.pcpartpicker.com/static/forever/i...   hard_drive
# 9980  https://m.media-amazon.com/images/I/31s-wKnYDv...   hard_drive
# 9981  https://m.media-amazon.com/images/I/51jzvyPoV6...   hard_drive
#
# [9982 rows x 2 columns]

# %%
label_counts = df["label"].value_counts().reset_index()
label_counts.columns = ["label", "count"]

sns.set_style("white")

plt.figure(figsize=(12,8))
barplot = sns.barplot(
    x="label",
    y="count",
    data=label_counts,
    palette="viridis",
    edgecolor="black",
    hue="label"
)

for patch in barplot.patches:
    height = patch.get_height()
    barplot.annotate(
        f"{int(height):,}",
        (patch.get_x() + patch.get_width() / 2, height),
        ha="center",
        va="bottom",
        fontsize=11,
        color="black",
        xytext=(0, 5),
        textcoords="offset points"
    )

plt.title("Cantidad de imágenes por tipo de componente", fontsize=20, weight="bold")
plt.xlabel("Componente", fontsize=14)
plt.ylabel("Cantidad", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

sns.despine(left=True, bottom=True)

plt.tight_layout()
plt.show()

# %%
labels = label_counts["label"]
sizes = label_counts["count"]
total_images = sizes.sum()

colors = plt.cm.tab20.colors[:len(labels)]

plt.figure(figsize=(10,10))

wedges, texts, autotexts = plt.pie(
    sizes,
    labels=labels,
    autopct="%1.1f%%",
    startangle=140,
    colors=colors,
    wedgeprops={"width":0.4, "edgecolor":"white", "linewidth":1.5},
    pctdistance=0.75,
    labeldistance=1.05
)

for autotext in autotexts:
    autotext.set_color("black")
    autotext.set_fontsize(12)
    autotext.set_weight("bold")

plt.text(0, 0, f"Total\n{total_images:,}", ha="center", va="center", fontsize=16, weight="bold")

plt.gca().set_aspect("equal")
plt.title("Distribución de imágenes por tipo de componente", fontsize=18, weight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusiones
#
# Hemos preparado un dataset que contiene **la etiqueta `label`** de cada componente y la **URL de su imagen**.
#
# En un **siguiente cuaderno**, descargaremos todas las imágenes localmente y las organizaremos por etiqueta, lo que permitirá **entrenar el modelo de manera más rápida y eficiente** sin depender de las descargas durante el entrenamiento.
